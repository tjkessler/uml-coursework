# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
trn_file = 'subset_train.csv'
val_file = 'subset_valid.csv'
tst_file = 'subset_test.csv'

# %%
ds_trn = pd.read_csv(trn_file)
ds_val = pd.read_csv(val_file)
ds_tst = pd.read_csv(tst_file)

# %%
ds_trn.describe()
# Out:
#                UDI  Air temperature [K]  Process temperature [K]  \
# count  6999.000000          6999.000000              6999.000000
# mean   5017.420346           300.000300               310.001172
# std    2884.967071             2.001965                 1.493597
# min       2.000000           295.300000               305.700000
# 25%    2508.500000           298.300000               308.800000
# 50%    5024.000000           300.100000               310.100000
# 75%    7512.500000           301.500000               311.100000
# max    9998.000000           304.400000               313.800000
#
#        Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Machine failure  \
# count             6999.000000  6999.000000      6999.000000      6999.000000
# mean              1539.425346    39.969253       108.042578         0.033862
# std                180.224620    10.012395        63.483750         0.180887
# ...

# %%
ds_val.describe()
# Out:
#                 UDI  Air temperature [K]  Process temperature [K]  \
# count   2000.000000          2000.000000              2000.000000
# mean    4951.405500           300.036850               310.032800
# std     2890.318409             1.990012                 1.452225
# min        4.000000           295.500000               305.900000
# 25%     2499.500000           298.300000               308.800000
# 50%     4935.500000           300.100000               310.100000
# 75%     7395.500000           301.600000               311.100000
# max    10000.000000           304.500000               313.800000
#
#        Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Machine failure  \
# count              2000.00000  2000.000000      2000.000000      2000.000000
# mean               1538.91300    39.923200       107.149000         0.034000
# std                 176.78728     9.771987        64.018958         0.181274
# ...

# %%
ds_tst.describe()
# Out:
#                UDI  Air temperature [K]  Process temperature [K]  \
# count  1001.000000          1001.000000              1001.000000
# mean   4980.283716           299.973526               309.981818
# std    2895.163735             2.009927                 1.477535
# min       1.000000           295.600000               306.000000
# 25%    2374.000000           298.300000               308.900000
# 50%    4947.000000           300.000000               310.000000
# 75%    7540.000000           301.400000               311.000000
# max    9994.000000           304.200000               313.500000
#
#        Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Machine failure  \
# count             1001.000000  1001.000000      1001.000000      1001.000000
# mean              1533.963037    40.237662       108.913087         0.033966
# std                177.741063    10.059814        64.157458         0.181232
# ...

# %%
targets = ['Machine failure','TWF','HDF','PWF','OSF','RNF']
trn_tgts = ds_trn[targets].sum(axis=0)
tst_tgts = ds_tst[targets].sum(axis=0)
val_tgts = ds_val[targets].sum(axis=0)

# %%
trn_tgts
# Out:
# Machine failure    237
# TWF                 28
# HDF                 83
# PWF                 72
# OSF                 65
# RNF                 16
# dtype: int64

# %%
tst_tgts
# Out:
# Machine failure    34
# TWF                 5
# HDF                10
# PWF                 9
# OSF                13
# RNF                 0
# dtype: int64

# %%
val_tgts
# Out:
# Machine failure    68
# TWF                13
# HDF                22
# PWF                14
# OSF                20
# RNF                 3
# dtype: int64
